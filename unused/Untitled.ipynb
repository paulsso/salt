# %%
from MatrixMethodTest import mainMatrixMethod

# %%
mainMatrixMethod(1, "Array", 0, 75e-3, 3, 6, 11, 18, 26, 32, 36, 40, 44, 60e-3, 40e3, 1e-6, 60e-3, 4.5e-3, 0, -1, "Array", 0, 75e-3, 3, 6, 11, 18, 0, 0, 0, 0, 0, 60e-3, 40e3, 1e-6, 60e-3, 4.5e-3, 0)
# Out:
# Creating array...
# Create array took 0.003003 seconds
# Creating array...
# Create array took 0.003003 seconds
# Creating medium...
# Creating medium took 0.001001 seconds
# Computing distance matrices...
# Computing distance matrices took 3.594774 seconds
# Computing transfer matrices...
# Computing transfer matrices took 9.697799 seconds
# Computing pressure matrix...
# Computing pressure matrices took 0.663604 seconds
# Computing relative acoustic potential...
# Computing relative acoustic potential took 0.001001 seconds
# (array([[-1.22223045e+09, -1.46527733e+09, -1.89058818e+09, ...,
#          -3.93244780e+09, -2.47141573e+09, -1.82401084e+09],
#         [-5.13960483e+08, -1.31938480e+09, -3.46849837e+09, ...,
#          -4.12866495e+09, -1.86114674e+09, -1.03803193e+09],
#         [-7.79294301e+08, -2.08979157e+09, -4.31458589e+09, ...,
#          -4.35700870e+09, -1.91264275e+09, -6.24170245e+08],
#         ...,
# ...
